# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#read in datasets
hospital_data = pd.read_csv("Resources/Complications and Deaths Hospital.csv")
national_data = pd.read_csv("Resources/Complications and Deaths National.csv")
state_data = pd.read_csv("Resources/Complications and Deaths State.csv", sep=',', error_bad_lines=False, index_col=False, dtype='unicode')

# %%
#check hospital dataset
hospital_data.head()
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701
# 1  DOTHAN    AL     36301     HOUSTON    3347938701
# 2  DOTHAN    AL     36301     HOUSTON    3347938701
# 3  DOTHAN    AL     36301     HOUSTON    3347938701
# 4  DOTHAN    AL     36301     HOUSTON    3347938701
#
#                                         Measure Name     Measure ID  \
# 0  Rate of complications for hip/knee replacement...  COMP_HIP_KNEE
# 1               Death rate for heart attack patients    MORT_30_AMI
# ...

# %%
#drop unneeded columns in speed camera locations dataset
hospital_data = hospital_data.drop(columns=["Measure Name", "Measure ID", "Measure End Date"])

# %%
#check national dataset
national_data.head()
# Out:
#                                         Measure Name     Measure ID  \
# 0  Rate of complications for hip/knee replacement...  COMP_HIP_KNEE
# 1               Death rate for heart attack patients    MORT_30_AMI
# 2               Death rate for CABG surgery patients   MORT_30_CABG
# 3                       Death rate for COPD patients   MORT_30_COPD
# 4              Death rate for heart failure patients     MORT_30_HF
#
#    National Rate  Number of Hospitals Worse  Number of Hospitals Same  \
# 0            2.6                         44                      2669
# 1           13.2                         24                      2376
# 2            3.1                         23                       984
# 3            8.3                         95                      3482
# 4           11.7                        135                      3379
#
#    Number of Hospitals Better Number of Hospitals Too Few  Footnote  \
# ...

# %%
#check state dataset
state_data.head()
# Out:
#   State                                       Measure Name     Measure ID  \
# 0    AK  Rate of complications for hip/knee replacement...  COMP_HIP_KNEE
# 1    AK               Death rate for heart attack patients    MORT_30_AMI
# 2    AK               Death rate for CABG surgery patients   MORT_30_CABG
# 3    AK                       Death rate for COPD patients   MORT_30_COPD
# 4    AK              Death rate for heart failure patients     MORT_30_HF
#
#   Number of Hospitals Worse Number of Hospitals Same  \
# 0                         0                        8
# 1                         0                        5
# 2                         0                        2
# 3                         0                       11
# 4                         0                        9
#
#   Number of Hospitals Better Number of Hospitals Too Few Footnote  \
# 0                          0                           1      NaN
# ...

# %%
# Merge the columns
combined_data = pd.merge(hospital_data, state_data, on="State", how="inner")

# %%
combined_data.head()
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701
# 1  DOTHAN    AL     36301     HOUSTON    3347938701
# 2  DOTHAN    AL     36301     HOUSTON    3347938701
# 3  DOTHAN    AL     36301     HOUSTON    3347938701
# 4  DOTHAN    AL     36301     HOUSTON    3347938701
#
#                   Compared to National Denominator       ...         \
# 0  No Different than the National Rate         315       ...
# 1  No Different than the National Rate         315       ...
# ...
